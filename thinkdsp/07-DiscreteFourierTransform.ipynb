# %% [markdown]
# # 07 - Discrete Fourier Transform

# %% [markdown]
# ## Complex Exponentials

# %% [markdown]
# ## Complex Signals

# %% [markdown]
# ## The Synthesis Problem

# %% [markdown]
# ## Synthesis with Matricies

# %% [markdown]
# ## The Analysis Problem

# %% [markdown]
# ## Efficient Analysis

# %% [markdown]
# ## DFT

# %% [markdown]
# ## The DFT is Periodic

# %% [markdown]
# ## DFT of Real Signals

# %% [markdown]
# ## Exercises
