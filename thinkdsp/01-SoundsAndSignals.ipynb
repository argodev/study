# %% [markdown]
# # 01 - Sounds and Signals

# %% [markdown]
# ## Periodic Signals

# %% [markdown]
# ## Spectral Decomposition

# %% [markdown]
# ## Signals

# %% [markdown]
# ## Reading and Writing Waves

# %% [markdown]
# ## Spectrums

# %% [markdown]
# ## Wave Objects

# %% [markdown]
# ## Signal Objects

# %% [markdown]
# ## Exercises
