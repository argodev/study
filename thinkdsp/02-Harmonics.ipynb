# %% [markdown]
# # 02 - Harmonics

# %% [markdown]
# ## Triangle Waves

# %% [markdown]
# ## Square Waves

# %% [markdown]
# ## Aliasing

# %% [markdown]
# ## Computing the Spectrum

# %% [markdown]
# ## Exercises
