# %% [markdown]
# # 05 - Autocorrelation

# %% [markdown]
# ## Correlation

# %% [markdown]
# ## Serial Correlation

# %% [markdown]
# ## Autocorrelation

# %% [markdown]
# ## Autocorrelation of Periodic Signals

# %% [markdown]
# ## Correlation as Dot Product

# %% [markdown]
# ## Using NumPy

# %% [markdown]
# ## Exercises
