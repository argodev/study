# %% [markdown]
# # 04 - Noise

# %% [markdown]
# ## Uncorrelated Noise

# %% [markdown]
# ## Integrated Spectrum

# %% [markdown]
# ## Brownian Noise

# %% [markdown]
# ## Pink Noise

# %% [markdown]
# ## Gaussian Noise

# %% [markdown]
# ## Exercises
