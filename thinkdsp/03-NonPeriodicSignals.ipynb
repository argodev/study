# %% [markdown]
# # 03 - Non-Periodic Signals

# %% [markdown]
# ## Linear Chirp

# %% [markdown]
# ## Exponential Chirp

# %% [markdown]
# ## Spectrum of a Chirp

# %% [markdown]
# ## Spectrogram

# %% [markdown]
# ## The Gabor Limit

# %% [markdown]
# ## Leakage

# %% [markdown]
# ## Windowing

# %% [markdown]
# ## Implementing Spectrograms

# %% [markdown]
# ## Exercises
