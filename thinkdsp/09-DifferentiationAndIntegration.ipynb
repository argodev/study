# %% [markdown]
# # 09 - Differentiation and Integration

# %% [markdown]
# ## Finite Differences

# %% [markdown]
# ## The Frequency Domain

# %% [markdown]
# ## Differentation

# %% [markdown]
# ## Integration

# %% [markdown]
# ## Cumulative Sum

# %% [markdown]
# ## Integrating Noise

# %% [markdown]
# ## Exercises
