# %% [markdown]
# # 10 - LTI Systems

# %% [markdown]
# ## Signals and Systems

# %% [markdown]
# ## Windows and Filters

# %% [markdown]
# ## Acoustic Response

# %% [markdown]
# ## Systems and Convolution

# %% [markdown]
# ## Proof of the Convolution Theorem

# %% [markdown]
# ## Exercises
