# %% [markdown]
# # 11 - Modulation and Sampling

# %% [markdown]
# ## Convolution with Impulses

# %% [markdown]
# ## Amplitude Modulation

# %% [markdown]
# ## Sampling

# %% [markdown]
# ## Aliasing

# %% [markdown]
# ## Interpolation

# %% [markdown]
# ## Exercises
