# %% [markdown]
# # 06 - Discrete Cosine Transform

# %% [markdown]
# ## Synthesis

# %% [markdown]
# ## Synthesis with Arrays

# %% [markdown]
# ## Analysis

# %% [markdown]
# ## Orthoganal Matricies

# %% [markdown]
# ## DCT-IV

# %% [markdown]
# ## Inverse DCT

# %% [markdown]
# ## The Dct Class

# %% [markdown]
# ## Exercises
